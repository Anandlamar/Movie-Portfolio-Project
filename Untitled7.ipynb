# %% [markdown]
# <a href="https://colab.research.google.com/github/Anandlamar/Movie-Portfolio-Project/blob/main/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)

pd.options.mode.chained_assignment = None



df = pd.read_csv(r'/content/movies.csv')

# %%
df
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life    NaN      Drama  2020
# 7664                                     Dream Round    NaN     Comedy  2020
# 7665                                   Saving Mbango    NaN      Drama  2020
# 7666                                    It's Just Us    NaN      Drama  2020
# 7667                                       Tee em el    NaN     Horror  2020
#
# ...

# %%
for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
# Out:
# name - 0%
# rating - 1%
# genre - 0%
# year - 0%
# released - 0%
# score - 0%
# votes - 0%
# director - 0%
# writer - 0%
# star - 0%
# country - 0%
# budget - 28%
# gross - 2%
# company - 0%
# runtime - 0%

# %%
print(df.dtypes)
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
df.boxplot(column=['gross'])
# Out:
# <Axes: >

# %%
df.drop_duplicates()
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life    NaN      Drama  2020
# 7664                                     Dream Round    NaN     Comedy  2020
# 7665                                   Saving Mbango    NaN      Drama  2020
# 7666                                    It's Just Us    NaN      Drama  2020
# 7667                                       Tee em el    NaN     Horror  2020
#
# ...

# %%
df.sort_values(by=['gross'], inplace=False, ascending=False)
# Out:
#                                             name rating   genre  year  \
# 5445                                      Avatar  PG-13  Action  2009
# 7445                           Avengers: Endgame  PG-13  Action  2019
# 3045                                     Titanic  PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13  Action  2015
# 7244                      Avengers: Infinity War  PG-13  Action  2018
# ...                                          ...    ...     ...   ...
# 7663                                More to Life    NaN   Drama  2020
# 7664                                 Dream Round    NaN  Comedy  2020
# 7665                               Saving Mbango    NaN   Drama  2020
# 7666                                It's Just Us    NaN   Drama  2020
# 7667                                   Tee em el    NaN  Horror  2020
#
#                                released  score      votes       director  \
# ...

# %%
sns.regplot(x="gross", y="budget", data=df)
# Out:
# <Axes: xlabel='gross', ylabel='budget'>

# %%
sns.regplot(x="score", y="gross", data=df)
# Out:
# <Axes: xlabel='score', ylabel='gross'>

# %%
df = df.apply(pd.to_numeric, errors='coerce')


df = df.dropna(axis=1, how='all')


correlation_matrix = df.corr(method='pearson')

print(correlation_matrix)
# Out:
#              name      year     score     votes    budget     gross   runtime
# name     1.000000 -0.377181  0.164244  0.063537  0.390134  0.275889  0.379230
# year    -0.377181  1.000000  0.097995  0.222945  0.329321  0.257486  0.120811
# score    0.164244  0.097995  1.000000  0.409182  0.076254  0.186258  0.399451
# votes    0.063537  0.222945  0.409182  1.000000  0.442429  0.630757  0.309212
# budget   0.390134  0.329321  0.076254  0.442429  1.000000  0.740395  0.320447
# gross    0.275889  0.257486  0.186258  0.630757  0.740395  1.000000  0.245216
# runtime  0.379230  0.120811  0.399451  0.309212  0.320447  0.245216  1.000000

# %%
df.corr(method ='kendall')
# Out:
#              name      year     score     votes    budget     gross   runtime
# name     1.000000 -0.270973  0.066262 -0.025641  0.127273  0.102564  0.307692
# year    -0.270973  1.000000  0.067652  0.331465  0.224120  0.200618  0.097184
# score    0.066262  0.067652  1.000000  0.300115 -0.000566  0.086046  0.283611
# votes   -0.025641  0.331465  0.300115  1.000000  0.353702  0.548899  0.198240
# budget   0.127273  0.224120 -0.000566  0.353702  1.000000  0.512637  0.235483
# gross    0.102564  0.200618  0.086046  0.548899  0.512637  1.000000  0.168933
# runtime  0.307692  0.097184  0.283611  0.198240  0.235483  0.168933  1.000000

# %%
df.corr(method ='spearman')
# Out:
#              name      year     score     votes    budget     gross   runtime
# name     1.000000 -0.382394  0.066484 -0.005495  0.081818  0.082418  0.439560
# year    -0.382394  1.000000  0.099045  0.469829  0.317336  0.293084  0.142977
# score    0.066484  0.099045  1.000000  0.428138 -0.001403  0.126116  0.399857
# votes   -0.005495  0.469829  0.428138  1.000000  0.502466  0.742050  0.290159
# budget   0.081818  0.317336 -0.001403  0.502466  1.000000  0.693670  0.336370
# gross    0.082418  0.293084  0.126116  0.742050  0.693670  1.000000  0.246243
# runtime  0.439560  0.142977  0.399857  0.290159  0.336370  0.246243  1.000000

# %%
correlation_matrix = df.corr()

sns.heatmap(correlation_matrix, annot = True)

plt.title("Correlation matrix for Numeric Features")

plt.xlabel("Movie features")

plt.ylabel("Movie features")

plt.show()

# %%
df.apply(lambda x: x.factorize()[0]).corr(method='pearson')
# Out:
#              name      year     score     votes    budget     gross   runtime
# name     1.000000  0.031790 -0.003768  0.031385  0.014120  0.031949  0.016283
# year     0.031790  1.000000 -0.044981  0.312401  0.300621  0.980873  0.050647
# score   -0.003768 -0.044981  1.000000 -0.009749 -0.012642 -0.047041  0.026436
# votes    0.031385  0.312401 -0.009749  1.000000  0.398519  0.286180  0.106024
# budget   0.014120  0.300621 -0.012642  0.398519  1.000000  0.285832  0.112097
# gross    0.031949  0.980873 -0.047041  0.286180  0.285832  1.000000  0.042978
# runtime  0.016283  0.050647  0.026436  0.106024  0.112097  0.042978  1.000000

# %%
correlation_matrix = df.apply(lambda x: x.factorize()[0]).corr(method='pearson')

sns.heatmap(correlation_matrix, annot = True)

plt.title("Correlation matrix for Movies")

plt.xlabel("Movie features")

plt.ylabel("Movie features")

plt.show()

# %%
correlation_mat = df.apply(lambda x: x.factorize()[0]).corr()

corr_pairs = correlation_mat.unstack()

print(corr_pairs)
# Out:
# name     name       1.000000
#          year       0.031790
#          score     -0.003768
#          votes      0.031385
#          budget     0.014120
#          gross      0.031949
#          runtime    0.016283
# year     name       0.031790
#          year       1.000000
#          score     -0.044981
#          votes      0.312401
#          budget     0.300621
#          gross      0.980873
#          runtime    0.050647
# score    name      -0.003768
#          year      -0.044981
#          score      1.000000
#          votes     -0.009749
#          budget    -0.012642
#          gross     -0.047041
#          runtime    0.026436
# votes    name       0.031385
#          year       0.312401
#          score     -0.009749
#          votes      1.000000
#          budget     0.398519
#          gross      0.286180
#          runtime    0.106024
# budget   name       0.014120
#          year       0.300621
#          score     -0.012642
#          votes      0.398519
# ...

# %%
sorted_pairs = corr_pairs.sort_values(kind="quicksort")

print(sorted_pairs)
# Out:
# gross    score     -0.047041
# score    gross     -0.047041
# year     score     -0.044981
# score    year      -0.044981
# budget   score     -0.012642
# score    budget    -0.012642
# votes    score     -0.009749
# score    votes     -0.009749
# name     score     -0.003768
# score    name      -0.003768
# name     budget     0.014120
# budget   name       0.014120
# runtime  name       0.016283
# name     runtime    0.016283
# runtime  score      0.026436
# score    runtime    0.026436
# votes    name       0.031385
# name     votes      0.031385
# year     name       0.031790
# name     year       0.031790
# gross    name       0.031949
# name     gross      0.031949
# gross    runtime    0.042978
# runtime  gross      0.042978
# year     runtime    0.050647
# runtime  year       0.050647
# votes    runtime    0.106024
# runtime  votes      0.106024
# budget   runtime    0.112097
# runtime  budget     0.112097
# gross    budget     0.285832
# budget   gross      0.285832
# ...

# %%
# Out:
# gross    year       0.980873
# year     gross      0.980873
# name     name       1.000000
# votes    votes      1.000000
# budget   budget     1.000000
# score    score      1.000000
# year     year       1.000000
# gross    gross      1.000000
# runtime  runtime    1.000000
# dtype: float64

# %%
strong_pairs = sorted_pairs[abs(sorted_pairs) > 0.5]

print(strong_pairs)
# Out:
# gross    year       0.980873
# year     gross      0.980873
# name     name       1.000000
# votes    votes      1.000000
# budget   budget     1.000000
# score    score      1.000000
# year     year       1.000000
# gross    gross      1.000000
# runtime  runtime    1.000000
# dtype: float64

# %%
df['company'] = df['name'].astype(str).str.extract(r'^(.+?)\b')

# %%
CompanyGrossSum = df.groupby('company')[["gross"]].sum()

CompanyGrossSumSorted = CompanyGrossSum.sort_values('gross', ascending = False)[:15]

CompanyGrossSumSorted = CompanyGrossSumSorted['gross'].astype('int64')

CompanyGrossSumSorted
# Out:
# company
# nan     584978151148
# 2012       791217826
# 300        456068181
# 1917       384623579
# 21         159808370
# 1408       132963417
# 42          97470701
# 9           48428063
# 2046        20205757
# 54          16757163
# 1984         8430492
# 1969         5979011
# 360          4396975
# 31            850419
# inf           195170
# Name: gross, dtype: int64

# %%
# Directly use the 'year' column to create the 'Year' column
df['Year'] = df['year'].astype(str).str[:4]
df
# Out:
#       name  year  score      votes      budget        gross  runtime company  \
# 0      NaN  1980    8.4   927000.0  19000000.0   46998772.0    146.0     nan
# 1      NaN  1980    5.8    65000.0   4500000.0   58853106.0    104.0     nan
# 2      NaN  1980    8.7  1200000.0  18000000.0  538375067.0    124.0     nan
# 3      NaN  1980    7.7   221000.0   3500000.0   83453539.0     88.0     nan
# 4      NaN  1980    7.3   108000.0   6000000.0   39846344.0     98.0     nan
# ...    ...   ...    ...        ...         ...          ...      ...     ...
# 7663   NaN  2020    3.1       18.0      7000.0          NaN     90.0     nan
# 7664   NaN  2020    4.7       36.0         NaN          NaN     90.0     nan
# 7665   NaN  2020    5.7       29.0     58750.0          NaN      NaN     nan
# 7666   NaN  2020    NaN        NaN     15000.0          NaN    120.0     nan
# 7667   NaN  2020    5.7        7.0         NaN          NaN    102.0     nan
#
#       Year
# 0     1980
# 1     1980
# ...

# %%
df.groupby(['company', 'year'])[["gross"]].sum()
# Out:
#                      gross
# company year
# 1408    2007  1.329634e+08
# 1917    2019  3.846236e+08
# 1969    1988  5.979011e+06
# 1984    1984  8.430492e+06
# 2012    2009  7.912178e+08
# 2046    2004  2.020576e+07
# 21      2008  1.598084e+08
# 300     2006  4.560682e+08
# 31      2016  8.504190e+05
# 360     2011  4.396975e+06
# 42      2013  9.747070e+07
# 54      1998  1.675716e+07
# 9       2009  4.842806e+07
# inf     1996  1.951700e+05
# nan     1980  2.483667e+09
#         1981  2.520065e+09
#         1982  3.187581e+09
#         1983  2.750005e+09
#         1984  3.524662e+09
#         1985  3.691509e+09
#         1986  3.647512e+09
#         1987  4.033434e+09
#         1988  4.834407e+09
#         1989  6.087251e+09
#         1990  6.804236e+09
#         1991  6.254771e+09
#         1992  7.334168e+09
#         1993  8.053959e+09
#         1994  9.062926e+09
#         1995  9.448305e+09
#         1996  9.819333e+09
#         1997  1.311228e+10
# ...

# %%
CompanyGrossSum = df.groupby(['company', 'year'])[["gross"]].sum()

CompanyGrossSumSorted = CompanyGrossSum.sort_values(['gross','company','year'], ascending = False)[:15]

CompanyGrossSumSorted = CompanyGrossSumSorted['gross'].astype('int64')

CompanyGrossSumSorted
# Out:
# company  year
# nan      2019    29955029462
#          2016    28937994373
#          2017    28485248415
#          2018    28085289459
#          2015    26746011088
#          2014    26491482563
#          2013    25898377973
#          2012    25476190195
#          2011    24833289861
#          2010    23106595534
#          2009    22499034720
#          2008    21542353639
#          2007    20250708382
#          2004    18701542055
#          2006    18198002182
# Name: gross, dtype: int64

# %%
CompanyGrossSum = df.groupby(['company'])[["gross"]].sum()

CompanyGrossSumSorted = CompanyGrossSum.sort_values(['gross','company'], ascending = False)[:15]

CompanyGrossSumSorted = CompanyGrossSumSorted['gross'].astype('int64')

CompanyGrossSumSorted
# Out:
# company
# nan     584978151148
# 2012       791217826
# 300        456068181
# 1917       384623579
# 21         159808370
# 1408       132963417
# 42          97470701
# 9           48428063
# 2046        20205757
# 54          16757163
# 1984         8430492
# 1969         5979011
# 360          4396975
# 31            850419
# inf           195170
# Name: gross, dtype: int64

# %%
plt.scatter(x=df['budget'], y=df['gross'], alpha=0.5)
plt.title('Budget vs Gross Earnings')
plt.xlabel('Gross Earnings')
plt.ylabel('Budget for Film')
plt.show()

# %%
df
# Out:
#       name  year  score      votes      budget        gross  runtime company  \
# 0      NaN  1980    8.4   927000.0  19000000.0   46998772.0    146.0     nan
# 1      NaN  1980    5.8    65000.0   4500000.0   58853106.0    104.0     nan
# 2      NaN  1980    8.7  1200000.0  18000000.0  538375067.0    124.0     nan
# 3      NaN  1980    7.7   221000.0   3500000.0   83453539.0     88.0     nan
# 4      NaN  1980    7.3   108000.0   6000000.0   39846344.0     98.0     nan
# ...    ...   ...    ...        ...         ...          ...      ...     ...
# 7663   NaN  2020    3.1       18.0      7000.0          NaN     90.0     nan
# 7664   NaN  2020    4.7       36.0         NaN          NaN     90.0     nan
# 7665   NaN  2020    5.7       29.0     58750.0          NaN      NaN     nan
# 7666   NaN  2020    NaN        NaN     15000.0          NaN    120.0     nan
# 7667   NaN  2020    5.7        7.0         NaN          NaN    102.0     nan
#
#       Year
# 0     1980
# 1     1980
# ...

# %%
df_numerized = df


for col_name in df_numerized.columns:
    if(df_numerized[col_name].dtype == 'object'):
        df_numerized[col_name]= df_numerized[col_name].astype('category')
        df_numerized[col_name] = df_numerized[col_name].cat.codes

df_numerized
# Out:
#       name  year  score      votes      budget        gross  runtime  company  \
# 0      NaN  1980    8.4   927000.0  19000000.0   46998772.0    146.0       14
# 1      NaN  1980    5.8    65000.0   4500000.0   58853106.0    104.0       14
# 2      NaN  1980    8.7  1200000.0  18000000.0  538375067.0    124.0       14
# 3      NaN  1980    7.7   221000.0   3500000.0   83453539.0     88.0       14
# 4      NaN  1980    7.3   108000.0   6000000.0   39846344.0     98.0       14
# ...    ...   ...    ...        ...         ...          ...      ...      ...
# 7663   NaN  2020    3.1       18.0      7000.0          NaN     90.0       14
# 7664   NaN  2020    4.7       36.0         NaN          NaN     90.0       14
# 7665   NaN  2020    5.7       29.0     58750.0          NaN      NaN       14
# 7666   NaN  2020    NaN        NaN     15000.0          NaN    120.0       14
# 7667   NaN  2020    5.7        7.0         NaN          NaN    102.0       14
#
#       Year
# 0        0
# ...

# %%
df_numerized.corr(method='pearson')
# Out:
#              name      year     score     votes    budget     gross   runtime  \
# name     1.000000 -0.377181  0.164244  0.063537  0.390134  0.275889  0.379230
# year    -0.377181  1.000000  0.097995  0.222945  0.329321  0.257486  0.120811
# score    0.164244  0.097995  1.000000  0.409182  0.076254  0.186258  0.399451
# votes    0.063537  0.222945  0.409182  1.000000  0.442429  0.630757  0.309212
# budget   0.390134  0.329321  0.076254  0.442429  1.000000  0.740395  0.320447
# gross    0.275889  0.257486  0.186258  0.630757  0.740395  1.000000  0.245216
# runtime  0.379230  0.120811  0.399451  0.309212  0.320447  0.245216  1.000000
# company -0.820739 -0.013683 -0.015334 -0.029555 -0.018216 -0.026110 -0.017332
# Year    -0.377181  1.000000  0.097995  0.222945  0.329321  0.257486  0.120811
#
#           company      Year
# name    -0.820739 -0.377181
# year    -0.013683  1.000000
# score   -0.015334  0.097995
# votes   -0.029555  0.222945
# budget  -0.018216  0.329321
# ...

# %%
correlation_matrix = df_numerized.corr(method='pearson')

sns.heatmap(correlation_matrix, annot = True)

plt.title("Correlation matrix for Movies")

plt.xlabel("Movie features")

plt.ylabel("Movie features")

plt.show()

# %%
for col_name in df.columns:
    if(df[col_name].dtype == 'object'):
        df[col_name]= df[col_name].astype('category')
        df[col_name] = df[col_name].cat.codes

# %%
cat_columns = df.select_dtypes(include=['object']).columns


df[cat_columns] = df[cat_columns].astype('category')
df[cat_columns] = df[cat_columns].apply(lambda x: x.cat.codes)

df
# Out:
#       name  year  score      votes      budget        gross  runtime  company  \
# 0      NaN  1980    8.4   927000.0  19000000.0   46998772.0    146.0       14
# 1      NaN  1980    5.8    65000.0   4500000.0   58853106.0    104.0       14
# 2      NaN  1980    8.7  1200000.0  18000000.0  538375067.0    124.0       14
# 3      NaN  1980    7.7   221000.0   3500000.0   83453539.0     88.0       14
# 4      NaN  1980    7.3   108000.0   6000000.0   39846344.0     98.0       14
# ...    ...   ...    ...        ...         ...          ...      ...      ...
# 7663   NaN  2020    3.1       18.0      7000.0          NaN     90.0       14
# 7664   NaN  2020    4.7       36.0         NaN          NaN     90.0       14
# 7665   NaN  2020    5.7       29.0     58750.0          NaN      NaN       14
# 7666   NaN  2020    NaN        NaN     15000.0          NaN    120.0       14
# 7667   NaN  2020    5.7        7.0         NaN          NaN    102.0       14
#
#       Year
# 0        0
# ...

# %%
sns.swarmplot(x="score", y="gross", data=df)
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3399: UserWarning: 33.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3399: UserWarning: 50.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3399: UserWarning: 25.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3399: UserWarning: 60.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
sns.stripplot(x="score", y="gross", data=df)
# Out:
# <Axes: xlabel='score', ylabel='gross'>
